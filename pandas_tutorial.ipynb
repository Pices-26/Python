# %%
import pandas as pd
import datetime
from pandas_datareader import data as web
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('ggplot')

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2015, 1, 1)

df = web.DataReader("XOM", "yahoo", start, end)

print(df.head())

df['Adj Close'].plot()

plt.show
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-01-04  69.260002  68.190002  68.720001  69.150002  27809100.0  51.284389
# 2010-01-05  69.449997  68.800003  69.190002  69.419998  30174700.0  51.484634
# 2010-01-06  70.599998  69.339996  69.449997  70.019997  35044700.0  51.929600
# 2010-01-07  70.059998  69.419998  69.900002  69.800003  27192100.0  51.766449
# 2010-01-08  69.750000  69.220001  69.690002  69.519997  24891800.0  51.558784
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

style.use('ggplot')

web_stats = {'Day' : [1,2,3,4,5,6],
             'Visitors' : [43,53,34,45,64,34],
             'Bounce_Rate' : [65,72,62,64,54,66]
            }
#df = what you want to call your data frame
df = pd.DataFrame(web_stats)

print(df)
#print(df.head()) prints first 5 rows
#print(df.tail()) prints last 5 rows

#print(df.tail(2)) prints last (specified)

#index = like primary key in sql

#way1
#new_df = df.set_index('Day')

#way2
df.set_index('Day', inplace=True)

#referencing a specific column
#print(df['Visitors']) way 1 usually for handling spaces in names
#print(df.Visitors) way 2

#print(df[['Bounce_Rate','Visitors']])  referencing more than 1 column

#print(df.Visitors.tolist()) prints Values from visitors

#print(np.array(df[['Bounce_Rate','Visitors']])) converting into an array

df2 = pd.DataFrame(np.array(df[['Bounce_Rate','Visitors']]))
print(df2)
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1        43           65
# 1    2        53           72
# 2    3        34           62
# 3    4        45           64
# 4    5        64           54
# 5    6        34           66
#     0   1
# 0  65  43
# 1  72  53
# 2  62  34
# 3  64  45
# 4  54  64
# 5  66  34

# %%
#IO BASICS
import pandas as pd

df = pd.read_csv('ZILLOW-M1300_MPPRAH.csv')

#print(df.head())

#df.set_index('Date', inplace=True)

#df.to_csv('newcsv2.csv') # exporting to csv

df = pd.read_csv('newcsv2.csv')
print(df.head())

#removes the counting index (specyfing date as index)
df = pd.read_csv('newcsv2.csv', index_col=0)
print(df.head())

#renaming columns (only if ther is 1 column)
df.columns = ['Austin_HPI']
print(df.head())

#saving to csv file 
#df.to_csv('newcsv3.csv') new header will be saved
#df.to_csv('newcsv4.csv', header=False) there will be no headers

#reading csv with no headers, you can name columns what you want
#df = pd.read_csv('newcsv4.csv' , names = ['Date', 'Austin_HPI'], index_col=0)

#converting
#df.to_html('example.html')

#renaming multiple columns
#dr.rename(columns={NAME OF THE COLUMN : NEW NAME OF THE COLUMN}, inplace=True)
# Out:
#          Date     Value
# 0  2019-01-31  3.258065
# 1  2018-12-31  2.710027
# 2  2018-11-30  3.031038
# 3  2018-10-31  3.543187
# 4  2018-09-30  3.284644
#                Value
# Date
# 2019-01-31  3.258065
# 2018-12-31  2.710027
# 2018-11-30  3.031038
# 2018-10-31  3.543187
# 2018-09-30  3.284644
#             Austin_HPI
# Date
# 2019-01-31    3.258065
# 2018-12-31    2.710027
# 2018-11-30    3.031038
# 2018-10-31    3.543187
# 2018-09-30    3.284644

# %%
#Building dataset for real estate analysis
import quandl
import pandas as pd

#api_key = ''

#df = quandl.get('FMAC/30US', authtoken=api_key)
#print(df.head())

#reading in american states from html
fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
#list
#print(fiddy_states)
#dataframe
#print(fiddy_states[0])
#getting column 2
print(fiddy_states[0])
# Out:
#                             Name Abbreviation          Cities                  \
#                             Name Abbreviation         Capital      Largest[3]
# 0                        Alabama           AL      Montgomery      Birmingham
# 1                         Alaska           AK          Juneau       Anchorage
# 2                        Arizona           AZ         Phoenix         Phoenix
# 3                       Arkansas           AR     Little Rock     Little Rock
# 4                     California           CA      Sacramento     Los Angeles
# 5                       Colorado           CO          Denver          Denver
# 6                    Connecticut           CT        Hartford      Bridgeport
# 7                       Delaware           DE           Dover      Wilmington
# 8                        Florida           FL     Tallahassee    Jacksonville
# 9                        Georgia           GA         Atlanta         Atlanta
# ...
